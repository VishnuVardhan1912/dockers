# %% [markdown]
# # AWS

# %% [markdown]
# ### AWS services
#
# * Amazon EC2
# * Amazon ECR
# * AWS Elastic Beanstalk
# * AWS Lambda
# * Auto Scaling
# * IAM
# * AWS KMS
# * Amazon S3
# * Amazon SES
# * Amazon RDS
# * Amazon Aurora
# * Amazon DynamoDB
# * Amazon ElastiCache
# * Amazon SQS
# * Amazon SNS
# * AWS Step Functions
# * Amazon CloudWatch
# * AWS Cloudformation
# * AWS Cloud Trall
# * Amazon API Gateway
# * Elastic Load Balancing
# * Amazon CouldFront
# * Amazon Kinesis
# * Amazon Route S3
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 1. AWS Certified Cloud Practitioner
# 2. AWS Certified Solutions Architect
# 3. AWS Certified Developer or AWS Certified SysOps Administrator.

# %% [markdown]
# A region is a cluster of data centers

# %% [markdown]
# # IAM: Users & Groups
#
# * IAM = Identity and Access Management, Global Service
# * Root account created by default, shouldn't be used or shared
# * users are people within your organization, and can be grouped.
# * Groups only contain users, not other groups
# * users don't have to belong to a group, and user can belong to multiple groups

# %% [markdown]
# #### Access Key
#
# * Access key is used for AWS CLI(command line interface) And AWS SDK (AWS CLI is built on AWS SDK for Python)
#
# #### AWS CLI
#
# * Create a access key(Access Key ID and Secret access key) for IAM user only
# * then Install AWS CLI MSI
# * Open command prompt
# * Type -- aws --version --- To check aws cli is installed or not
# * To enter type -- aws configure
#                  * AWS Access Key ID : AKDFLSKDKFSNl
#                  * AWS Secret Access Key : iaufdhi*na
#                  * Default region name : eu-west-1
# * To check all the users in the account : aws iam list-users

# %% [markdown]
# #### AWS CloudShell
#
# AWS CloudShell alternate of AWS CLI for web
#
# * For Region -- aws iam list-users --region
# * To create a file -- echo "test" > demo.txt
# * to see the file -- cat demo.txt

# %% [markdown]
# #### Amazon EC2 Fundamentals

# %% [markdown]
# Amazon EC2 = Elastic Compute Cloud = Infrastructure as a Service

# %% [markdown]
# * It mainly consists in the capability of:
#     * Renting virtual machines (EC2)
#     * Storing data on virtual drives (EBS)
#     * Distributing load across machines (ELB)
#     * Scaling the services using an auto-scaling group (ASG)

# %% [markdown]
# key pair (login) instance -- this is used when we use ssh to access the instance
#
# Key pair name: EC2 Tutorial
#
# Key pair type : RSA
#
# Private key file format
#
# .pem (for use with OpenSSH) -- mac, linux, windows 10
#
# .ppk(For use with PuTTY) -- windows 7 & 8
#
#
# Network Settings
#
# To allow traffic -- Allow SSH traffic and Allow HTTP traffic
#
# user data -- to excute on first lanch we use scripts
#
# After launching --
#
# public IPV4 address is used to launch EC2
# private IPV4 addresses is used to access internally AWS network on private.
